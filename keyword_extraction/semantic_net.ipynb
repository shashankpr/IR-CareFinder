# %%
from pattern.graph import Graph

# %%
g = Graph() 
g.add_edge('hip_replacement', 'illness', type='is-a') # bone_fracture is-a illness 
g.add_edge('break', 'hip_replacement', type='is-property-of') 
g.add_edge('hip_replacement', 'orthopedic', type='is-related-to') 
 
node = g['hip_replacement'] 
print node.id
print node.links
# Out:
# hip_replacement
# [Node(id='illness'), Node(id='break'), Node(id='orthopedic')]

# %%
from pattern.db import CSV

# %%
g = Graph()

# %%
data = 'commonsense.csv'
data = CSV.load(data) 
for concept1, relation, concept2, context, weight in data: 
    g.add_edge( 
        concept1, 
        concept2, 
          type = relation, 
        weight = min(int(weight) * 0.1, 1.0))

# %%
print g
# Out:
# {u'fawn': Node(id=u'fawn'), u'ladybird': Node(id=u'ladybird'), u'dynamic': Node(id=u'dynamic'), u'yellow': Node(id=u'yellow'), u'four': Node(id=u'four'), u'woods': Node(id=u'woods'), u'sleep': Node(id=u'sleep'), u'heavy metal': Node(id=u'heavy metal'), u'appetite': Node(id=u'appetite'), u'hate': Node(id=u'hate'), u'shamble': Node(id=u'shamble'), u'maidenhair': Node(id=u'maidenhair'), u'electricity': Node(id=u'electricity'), u'spin': Node(id=u'spin'), u'swan': Node(id=u'swan'), u'Scottsdale': Node(id=u'Scottsdale'), u's57': Node(id=u's57'), u's56': Node(id=u's56'), u'Vulcan': Node(id=u'Vulcan'), u'goa trance': Node(id=u'goa trance'), u's51': Node(id=u's51'), u's50': Node(id=u's50'), u'pride': Node(id=u'pride'), u'Akzidenz-Grotesk': Node(id=u'Akzidenz-Grotesk'), u'Uffizi': Node(id=u'Uffizi'), u'merchant': Node(id=u'merchant'), u'@': Node(id=u'@'), u'hormone': Node(id=u'hormone'), u'Donald Duck': Node(id=u'Donald Duck'), u'risk': Node(id=u'risk'), u'geology': Node(id=u'geology'), u'cemetary': Node(id=u'cemetary'), u'void': Node(id=u'void'), u'citrus': Node(id=u'citrus'), u'shoot': Node(id=u'shoot'), u'capoeira': Node(id=u'capoeira'), u'construction worker': Node(id=u'construction worker'), u'microbe': Node(id=u'microbe'), u'uncertain': Node(id=u'uncertain'), u'vast': Node(id=u'vast'), u'school': Node(id=u'school'), u'prize': Node(id=u'prize'), u'parrot': Node(id=u'parrot'), u'daydream': Node(id=u'daydream'), u'wednesday': Node(id=u'wednesday'), u'tasmanian devil': Node(id=u'tasmanian devil'), u'nigger': Node(id=u'nigger'), u'math': Node(id=u'math'), u'poppy': Node(id=u'poppy'), u'light bulb': Node(id=u'light bulb'), u'heading': Node(id=u'heading'), u'triumph': Node(id=u'triumph'), u'R\xf6ntgen': Node(id=u'R\xf6ntgen'), u'Sicily': Node(id=u'Sicily'), u'bicycle': Node(id=u'bicycle'), u'monotonous': Node(id=u'monotonous'), u'eagle': Node(id=u'eagle'), u'Edda': Node(id=u'Edda'), u'almond': Node(id=u'almond'), u'direct': Node(id=u'direct'), u'horn': Node(id=u'horn'), u'elegant': Node(id=u'elegant'), u'ebony': Node(id=u'ebony'), u'satellite dish': Node(id=u'satellite dish'), u'The A-team': Node(id=u'The A-team'), u'copyleft': Node(id=u'copyleft'), u'broken heart': Node(id=u'broken heart'), u'panda': Node(id=u'panda'), u'theory': Node(id=u'theory'), u'blue': Node(id=u'blue'), u'LSD': Node(id=u'LSD'), u'Arizona': Node(id=u'Arizona'), u'hide': Node(id=u'hide'), u'organisms': Node(id=u'organisms'), u'pace': Node(id=u'pace'), u'thunder': Node(id=u'thunder'), u'Zeus': Node(id=u'Zeus'), u'C-3PO': Node(id=u'C-3PO'), u'hazy': Node(id=u'hazy'), u'Mazda': Node(id=u'Mazda'), u'fjord': Node(id=u'fjord'), u'random generator': Node(id=u'random generator'), u'blur': Node(id=u'blur'), u'new': Node(id=u'new'), u'carpet': Node(id=u'carpet'), u'litchi': Node(id=u'litchi'), u'Chula Vista': Node(id=u'Chula Vista'), u'business lunch': Node(id=u'business lunch'), u'reporter': Node(id=u'reporter'), u'herb': Node(id=u'herb'), u'even': Node(id=u'even'), u'mountain ash': Node(id=u'mountain ash'), u'herd': Node(id=u'herd'), u'anthropology': Node(id=u'anthropology'), u'fun': Node(id=u'fun'), u'Cookie Monster': Node(id=u'Cookie Monster'), u'Ferrari': Node(id=u'Ferrari'), u'pursuit': Node(id=u'pursuit'), u'dogwood': Node(id=u'dogwood'), u'cult': Node(id=u'cult'), u'Ohio': Node(id=u'Ohio'), u'cardboard': Node(id=u'cardboard'), u'X-ray': Node(id=u'X-ray'), u'celebration': Node(id=u'celebration'), u'dry': Node(id=u'dry'), u'guanaco': Node(id=u'guanaco'), u'lychee': Node(id=u'lychee'), u'moustache': Node(id=u'moustache'), u'settler': Node(id=u'settler'), u'economics': Node(id=u'economics'), u'monospaced': Node(id=u'monospaced'), u'Orc': Node(id=u'Orc'), u'jogging': Node(id=u'jogging'), u'Las Vegas': Node(id=u'Las Vegas'), u'smoke': Node(id=u'smoke'), u'mistake': Node(id=u'mistake'), u'head': Node(id=u'head'), u'Audi': Node(id=u'Audi'), u'Honda': Node(id=u'Honda'), u'straw': Node(id=u'straw'), u'spooky': Node(id=u'spooky'), u'patience': Node(id=u'patience'), u'Stone Serif ...

# %%
def halo(node, depth=2): 
    return node.flatten(depth)

# %%
def field(node, depth=3, fringe=2): 
    def traversable(node, edge): 
        return edge.node2 == node and edge.type == 'is-a'
    g = node.graph.copy(nodes=node.flatten(depth, traversable)) 
    g = g.fringe(depth=fringe) 
    g = [node.graph[n.id] for n in g if n != node] 
    return g

# %%
PROPERTIES = [e.node1.id for e in g.edges if e.type == 'is-property-of'] 
PROPERTIES = dict.fromkeys(PROPERTIES, True)

# %%
cache = {} # Cache results for faster reuse.
  
def properties(node): 
    if node.id in cache: 
        return cache[node.id] 
    g = node.graph.copy(nodes=halo(node)) 
    p = (n for n in g.nodes if n.id in PROPERTIES) 
    p = reversed(sorted(p, key=lambda n: n.centrality)) 
    p = [node.graph[n.id] for n in p] 
    cache[node.id] = p 
    return p

# %%
def similarity(node1, node2, k=3): 
    g = node1.graph 
    h = lambda id1, id2: 1 - int(g.edge(id1, id2).type == 'is-property-of') 
    w = 0.0
    for p1 in properties(node1)[:k]: 
        for p2 in properties(node2)[:k]: 
            p = g.shortest_path(p1, p2, heuristic=h) 
            w += 1.0 / (p is None and 1e10 or len(p)) 
    return w / k

# %%
def nearest_neighbors(node, candidates=[], k=3): 
    w = lambda n: similarity(node, n, k) 
    return sorted(candidates, key=w, reverse=True)

# %%
print nearest_neighbors(g['creepy'], field(g['animal']))
# Out:
# [Node(id=u'vulture'), Node(id=u'octopus'), Node(id=u'bat'), Node(id=u'wolf'), Node(id=u'piranha'), Node(id=u'mole'), Node(id=u'grizzly'), Node(id=u'raven'), Node(id=u'owl'), Node(id=u'rhinoceros'), Node(id=u'sea urchin'), Node(id=u'tick'), Node(id=u'spider'), Node(id=u'vampire'), Node(id=u'earthworm'), Node(id=u'Sleipnir'), Node(id=u'crow'), Node(id=u'Cheshire Cat'), Node(id=u'reptile'), Node(id=u'fish'), Node(id=u'arachnid'), Node(id=u'pit bull'), Node(id=u'worm'), Node(id=u'parrot'), Node(id=u'turtle'), Node(id=u'toad'), Node(id=u'amphibian'), Node(id=u'gnu'), Node(id=u'panther'), Node(id=u'caterpillar'), Node(id=u'scorpion'), Node(id=u'panda'), Node(id=u'invertebrate'), Node(id=u'eagle'), Node(id=u'penguin'), Node(id=u'snail'), Node(id=u'slug'), Node(id=u'bird of prey'), Node(id=u'cockroach'), Node(id=u'clam'), Node(id=u'snake'), Node(id=u'cat'), Node(id=u'crocodile'), Node(id=u'tasmanian devil'), Node(id=u'hippopotamus'), Node(id=u'salamander'), Node(id=u'boar'), Node(id=u'dove'), Node(id=u'dinosaur'), Node(id=u'butterfly'), Node(id=u'rat'), Node(id=u'shark'), Node(id=u'stallion'), Node(id=u'goose'), Node(id=u'coyote'), Node(id=u'kitten'), Node(id=u'dragonfly'), Node(id=u'moth'), Node(id=u'insect'), Node(id=u'mayfly'), Node(id=u'beetle'), Node(id=u'marine'), Node(id=u'cricket'), Node(id=u'donkey'), Node(id=u'coelenterate'), Node(id=u'monkey'), Node(id=u'lobster'), Node(id=u'bee'), Node(id=u'flea'), Node(id=u'canary'), Node(id=u'tortoise'), Node(id=u'alligator'), Node(id=u'lizard'), Node(id=u'anemone'), Node(id=u'albatross'), Node(id=u'goat'), Node(id=u'centipede'), Node(id=u'ferret'), Node(id=u'tiger'), Node(id=u'wasp'), Node(id=u'chameleon'), Node(id=u'child'), Node(id=u'sloth'), Node(id=u'ewe'), Node(id=u'fruit feeder'), Node(id=u'jellyfish'), Node(id=u'fly'), Node(id=u'camel'), Node(id=u'kangaroo'), Node(id=u'marmot'), Node(id=u'tarantula'), Node(id=u'seal'), Node(id=u'mollusk'), Node(id=u'bear'), Node(id=u'puma'), Node(id=u'jaguar'), Node(id=u'leopard'), Node(id=u'cougar'), Node(id=u'ocelot'), Node(id=u'lynx'), Node(id=u'cheetah'), Node(id=u'mustang'), Node(id=u'elk'), Node(id=u'pigeon'), Node(id=u'rodent'), Node(id=u'anteater'), Node(id=u'dog'), Node(id=u'gazelle'), Node(id=u'hummingbird'), Node(id=u'puppy'), Node(id=u'coral'), Node(id=u'waterbird'), Node(id=u'stag'), Node(id=u'mosquito'), Node(id=u'lemming'), Node(id=u'hamster'), Node(id=u'goldfish'), Node(id=u'frog'), Node(id=u'dolphin'), Node(id=u'gorilla'), Node(id=u'dingo'), Node(id=u'hyena'), Node(id=u'Snoopy'), Node(id=u'pelican'), Node(id=u'Azrael'), Node(id=u'crustacean'), Node(id=u'doe'), Node(id=u'mammal'), Node(id=u'grasshopper'), Node(id=u'locust'), Node(id=u'termite'), Node(id=u'crane'), Node(id=u'antelope'), Node(id=u'fox'), Node(id=u'jackal'), Node(id=u'swan'), Node(id=u'meat'), Node(id=u'squirrel'), Node(id=u'chicken'), Node(id=u'porcupine'), Node(id=u'mouse'), Node(id=u'squid'), Node(id=u'polar bear'), Node(id=u'otter'), Node(id=u'beaver'), Node(id=u'reindeer'), Node(id=u'bird'), Node(id=u'lion'), Node(id=u'horse'), Node(id=u'tapir'), Node(id=u'colt'), Node(id=u'burro'), Node(id=u'hedgehog'), Node(id=u'gopher'), Node(id=u'sponge'), Node(id=u'mare'), Node(id=u'Lassie'), Node(id=u'deer'), Node(id=u'llama'), Node(id=u'angelfish'), Node(id=u'rooster'), Node(id=u'elephant'), Node(id=u'weasel'), Node(id=u'heron'), Node(id=u'sheep'), Node(id=u'pig'), Node(id=u'daddy-long-legs'), Node(id=u'primate'), Node(id=u'ass'), Node(id=u'orangutan'), Node(id=u'baboon'), Node(id=u'mandrill'), Node(id=u'chimpanzee'), Node(id=u'ape'), Node(id=u'marmoset'), Node(id=u'whale'), Node(id=u'pony'), Node(id=u'zebra'), Node(id=u'praying mantis'), Node(id=u'badger'), Node(id=u'flightless'), Node(id=u'mockingbird'), Node(id=u'duck'), Node(id=u'hamburger'), Node(id=u'woman'), Node(id=u'human'), Node(id=u'salmon'), Node(id=u'walrus'), Node(id=u'ant'), Node(id=u'cockatoo'), Node(id=u'budgerigar'), Node(id=u'lovebird'), Node(id=u'parakeet'), Node(id=u'lorikeet'), Node(id=u'fawn'), Node ...

# %%
from pattern.web import Google, plaintext 
from pattern.search import search 
 
def learn(concept): 
    q = 'I think %s is *' %concept 
    p = [] 
    g = Google(license='AIzaSyB6Ld4LCKq3kAhcmp0Hkfby909CQqvbZ8w', language='en') 
    for i in range(10): 
        for result in g.search(q, start=i, cached=True): 
            #print result
            m = plaintext(result.description) 
            m = search(q, m) # use * as wildcard 
            #print m
            if m: 
                p.append(m[0][-1].string) 
    return [w for w in p if w in PROPERTIES]

# %%
#t = learn("England")
#print t
for p in learn('England'):
    #print p
    g.add_edge(p, 'England', type='is-property-of')

# %%
print nearest_neighbors(g['England'], field(g['animal']))
# Out:
# [Node(id=u'praying mantis'), Node(id=u'stag'), Node(id=u'bird of prey'), Node(id=u'lion'), Node(id=u'rooster'), Node(id=u'vampire'), Node(id=u'mockingbird'), Node(id=u'badger'), Node(id=u'panther'), Node(id=u'bat'), Node(id=u'dolphin'), Node(id=u'grizzly'), Node(id=u'panda'), Node(id=u'donkey'), Node(id=u'mosquito'), Node(id=u'falcon'), Node(id=u'hawk'), Node(id=u'osprey'), Node(id=u'raptor'), Node(id=u'goose'), Node(id=u'rhinoceros'), Node(id=u'cat'), Node(id=u'dove'), Node(id=u'scorpion'), Node(id=u'lemming'), Node(id=u'piranha'), Node(id=u'boar'), Node(id=u'mare'), Node(id=u'horse'), Node(id=u'tapir'), Node(id=u'colt'), Node(id=u'stallion'), Node(id=u'burro'), Node(id=u'kangaroo'), Node(id=u'eagle'), Node(id=u'mouse'), Node(id=u'crow'), Node(id=u'raven'), Node(id=u'goldfish'), Node(id=u'sheep'), Node(id=u'albatross'), Node(id=u'hippopotamus'), Node(id=u'ferret'), Node(id=u'child'), Node(id=u'doe'), Node(id=u'reptile'), Node(id=u'Sleipnir'), Node(id=u'caterpillar'), Node(id=u'hamster'), Node(id=u'snake'), Node(id=u'chicken'), Node(id=u'dog'), Node(id=u'bee'), Node(id=u'mole'), Node(id=u'gnu'), Node(id=u'swan'), Node(id=u'frog'), Node(id=u'elephant'), Node(id=u'coral'), Node(id=u'monkey'), Node(id=u'shark'), Node(id=u'gazelle'), Node(id=u'dingo'), Node(id=u'Snoopy'), Node(id=u'deer'), Node(id=u'puma'), Node(id=u'jaguar'), Node(id=u'leopard'), Node(id=u'tiger'), Node(id=u'cougar'), Node(id=u'ocelot'), Node(id=u'lynx'), Node(id=u'cheetah'), Node(id=u'mustang'), Node(id=u'parrot'), Node(id=u'toad'), Node(id=u'crocodile'), Node(id=u'tasmanian devil'), Node(id=u'camel'), Node(id=u'turtle'), Node(id=u'crane'), Node(id=u'owl'), Node(id=u'gorilla'), Node(id=u'polar bear'), Node(id=u'rat'), Node(id=u'wolf'), Node(id=u'centipede'), Node(id=u'dinosaur'), Node(id=u'whale'), Node(id=u'vulture'), Node(id=u'goat'), Node(id=u'pigeon'), Node(id=u'fly'), Node(id=u'anteater'), Node(id=u'pony'), Node(id=u'ant'), Node(id=u'ewe'), Node(id=u'sloth'), Node(id=u'bear'), Node(id=u'zebra'), Node(id=u'Azrael'), Node(id=u'man'), Node(id=u'salamander'), Node(id=u'clam'), Node(id=u'Cheshire Cat'), Node(id=u'elk'), Node(id=u'invertebrate'), Node(id=u'kitten'), Node(id=u'flea'), Node(id=u'gopher'), Node(id=u'waterbird'), Node(id=u'marine'), Node(id=u'squirrel'), Node(id=u'reindeer'), Node(id=u'mammal'), Node(id=u'arachnid'), Node(id=u'woman'), Node(id=u'coyote'), Node(id=u'fish'), Node(id=u'anemone'), Node(id=u'tarantula'), Node(id=u'weasel'), Node(id=u'marmot'), Node(id=u'antelope'), Node(id=u'seal'), Node(id=u'snail'), Node(id=u'slug'), Node(id=u'amphibian'), Node(id=u'butterfly'), Node(id=u'cockroach'), Node(id=u'otter'), Node(id=u'beaver'), Node(id=u'primate'), Node(id=u'ass'), Node(id=u'orangutan'), Node(id=u'baboon'), Node(id=u'mandrill'), Node(id=u'chimpanzee'), Node(id=u'ape'), Node(id=u'marmoset'), Node(id=u'tortoise'), Node(id=u'alligator'), Node(id=u'lizard'), Node(id=u'porcupine'), Node(id=u'rodent'), Node(id=u'bird'), Node(id=u'octopus'), Node(id=u'hamburger'), Node(id=u'coelenterate'), Node(id=u'llama'), Node(id=u'puppy'), Node(id=u'jellyfish'), Node(id=u'bonobo'), Node(id=u'earthworm'), Node(id=u'worm'), Node(id=u'pit bull'), Node(id=u'fruit feeder'), Node(id=u'pig'), Node(id=u'grasshopper'), Node(id=u'walrus'), Node(id=u'human'), Node(id=u'lobster'), Node(id=u'cricket'), Node(id=u'sea urchin'), Node(id=u'wasp'), Node(id=u'flightless'), Node(id=u'duck'), Node(id=u'soar'), Node(id=u'meat'), Node(id=u'tick'), Node(id=u'spider'), Node(id=u'heron'), Node(id=u'dragonfly'), Node(id=u'moth'), Node(id=u'insect'), Node(id=u'mayfly'), Node(id=u'beetle'), Node(id=u'hedgehog'), Node(id=u'locust'), Node(id=u'termite'), Node(id=u'hyena'), Node(id=u'chameleon'), Node(id=u'fawn'), Node(id=u'kid'), Node(id=u'pelican'), Node(id=u'crustacean'), Node(id=u'Garfield'), Node(id=u'penguin'), Node(id=u'Lassie'), Node(id=u'salmon'), Node(id=u'fox'), Node(id=u'jackal'), Node(id=u'canary'), Node(id=u'daddy-long-legs'), Node(id=u'squid'), Node(id=u'sponge'), Node(id=u'Sha ...

# %%
print nearest_neighbors(g['England'], field(g['person'],2,1))
# Out:
# [Node(id=u'Abraham Lincoln'), Node(id=u'David Carson'), Node(id=u'H. P. Lovecraft'), Node(id=u'Jerry Springer'), Node(id=u'man'), Node(id=u'woman'), Node(id=u'Arnold Schwarzenegger'), Node(id=u'Daniel Craig'), Node(id=u'Harvey Keitel'), Node(id=u'Adolf Hitler'), Node(id=u'Al Capone'), Node(id=u'John Cleese'), Node(id=u'communicator'), Node(id=u'innovator'), Node(id=u'Jesus Christ'), Node(id=u'Nicola Tesla'), Node(id=u'Alfred Hitchcock'), Node(id=u'John Baskerville'), Node(id=u'Thomas More'), Node(id=u'Neil Armstrong'), Node(id=u'problem solver'), Node(id=u'Adrian Frutiger'), Node(id=u'Giambattista Bodoni'), Node(id=u'Mark Zuckerberg'), Node(id=u'Leonardo da Vinci'), Node(id=u'referee'), Node(id=u'Martin Luther King'), Node(id=u'Matthew Carter'), Node(id=u'Albert Einstein'), Node(id=u'Osama Bin Laden'), Node(id=u'Karl Marx'), Node(id=u'Leonard Nimoy'), Node(id=u'loner'), Node(id=u'Christophe Plantin'), Node(id=u'Jonathan Barnbrook'), Node(id=u'Donald Knuth'), Node(id=u'Pierre B\xe9zier'), Node(id=u'Wim Crouwel'), Node(id=u'Firmin Didot'), Node(id=u'Erik Spiekermann'), Node(id=u'Eric Gill'), Node(id=u'Susan Kare'), Node(id=u'Hermann Zapf'), Node(id=u'Claude Garamond'), Node(id=u'Jean-Fran\xe7ois Porchez'), Node(id=u'Neville Brody'), Node(id=u'Paul Rand'), Node(id=u'integrator'), Node(id=u'Frank Herbert'), Node(id=u'Erik Van Blokland'), Node(id=u'Charles Darwin'), Node(id=u'Erwin Schr\xf6dinger'), Node(id=u'David Hasselhoff'), Node(id=u'Just Van Rossum'), Node(id=u'Isaac Newton'), Node(id=u'Dustin Hoffman')]

# %%
g.export('test',directed=True, frames = 1, ipf=0)
